# %% [markdown]
# # **Final Project**
# ## *DATA 5420/6420*
# ## Name: Dallin Moore
#
# The purpose of the final project is to produce an MVP that is a culmination of the skills you have learned in each of the previous units. This MVP should be a cohesive product in that it combines methods in some logical pipeline, it should NOT simply be a collection of methods implemented independently/separately with no clear end goal/state. You will be tasked with applying at least four methods from across the four units, which I've outlined below:
#
# ### Unit 1
#
# * Chatbots
# * Basic Text Statistics
# * NLP Pipeline (Preprocessing & Normalization)
# * Compiling Corpora via APIs
#
# ### Unit 2
#
# * Bag of Words Models (TF-IDF and Count Vectorization)
# * Document Classification
# * Sentiment Analysis
#
# ### Unit 3
#
# * Document Summarization
# * Topic Modeling
# * Text Similarity
# > * Information Retrieval (Search)
# > * Recommendation Systems
# * Document Clustering
# > * KMeans
# > * Affinity Prop
# > * Wards Agglomerative Hierarchical
#
# ### Unit 4
#
# * Word Embeddings
# * Pretrained Transformers
# * Question-Answering Systems
# * Speech-to-Text (hopefully)
#
# You will of course need to perform some form of cleaning/text normalization and feature engineering (bag of words and/or word embeddings), but the way you go about that will be problem dependent -- on top of those two steps, you will need to incorporate at least two other model types as well that form some coherent end-stage MVP.
#
# For example:
#
# 1) corpus of a news articles pulled from the Bing News API that is cleaned/normalized
#
# 2) uses word embeddings to feature engineer the text
#
# 3) performs sentiment analysis to score sentiment of all articles
#
# 4) articles are sortable by sentiment, and ranked based on their relevance to keywords/search queries (information retrieval)
#
# The MVP is a NewsFeed showing a table of articles displayed in an interactive dashboard
#
# As you are performing your analyses consider:
#
# * What cleaning and normalization steps are necessary for my text, and which are not?
# * What sort of feature engineering do I need to utilize, both in terms of using BoW or word embeddings, and in terms of document or word vectorization? Do I need to use different methods for different analysis types?
# * What is the purpose of performing your selected methods and how do they meaningful build on one another?
# * What are the practical applications of the models you developed?

# %% [markdown]
# ### **What methods have you chosen and how do they fit together?**
#
#
#
# - **Method 1** – NLP Pipeline (Preprocessing & Normalization)
#  - Preprocessing steps include, removing stopwords, and lemmatization. The lyrics will be tokenized on by line.
# - **Method 2** – Context Embeddings (SBERT)
#  - Use word embddings to create feature representations of song lyrics, which can be further utilized for the other steps.
# - **Method 3** – Document Clustering (KMeans/DBSCAN)
#  - Apply a clustering algorithm (probably KMeans) to the selected similar songs to group them into clusters. Create a labeled dataset to use for my MVP.
# - **Method 4** – Text Similarity (Recommendation System)
#  - Compute the similarity between the input song's lyrics and all other songs in the dataset. Identify the top N most similar songs to the input song based on their lyrics.
#
#
# **How these methods will be meaningfully combined**:
#
# The user will have the option of either choosing a specific theme, entering a prompt, or both to create a unique playlist with links to each of the songs on Spotify. Using Streamlit to develop an MVP, there will simply be a title, a dropdown of themes, a search bar, and space for the output with links.

# %% [markdown]
# ## **Imports** (Dependencies and Files)

# %%
# !pip install langdetect
# !pip install -U sentence-transformers
from langdetect import detect
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import re
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from scipy.spatial.distance import euclidean

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# %%
df_all_songs = pd.read_csv('C:/Users/04drm/Downloads/data_5420/data_5420/Spotify-Million-Song-Dataset.csv')
df_all_songs.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  She's My Kind Of Girl  /a/abba/shes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %% [markdown]
# ### **Method 1** – NLP Pipeline (Preprocessing & Normalization)

# %% [markdown]
# There are some songs that are not in English that will be removed.

# %%
def is_english(text):
    try:
        lang = detect(text)
        return lang == 'en'
    except:
        return False

# %%
df_all_songs['IsEnglish'] = df_all_songs['text'].apply(is_english)
df = df_all_songs[df_all_songs['IsEnglish']]
df = df.drop(columns=['IsEnglish'])
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# Preprocess the textby removing stopwords, lemmatizing text, normalizing text, etc.

# %%
def preprocess(text):
    lines_output = []
    lines = text.split('\n')
    for text in lines:
        text = text.lower()
        stop_words = set(stopwords.words('english')) # stopword removal
        stop_words.update(['chorus'])
        text = ' '.join([word for word in text.split() if word not in stop_words])
        text = text.translate(str.maketrans('', '', string.punctuation)) # Remove punctuation
        text = re.sub(r'\d+', '', text) # Remove numerical data
        text = re.sub(r'[^a-zA-Z\s]', '', text) # Remove special characters/symbols
        # Lemmatize text
        lemmatizer = WordNetLemmatizer()
        text = ' '.join([lemmatizer.lemmatize(word) for word in text.split(' ')])
        if len(text) > 0:
          lines_output.append(text)
        
    return ' '.join(lines_output)

df['preprocessed_text'] = df['text'].apply(preprocess)
print(df['preprocessed_text'].head())
# Out:
# 0    look face wonderful face mean something specia...
# 1    take easy me please touch gently like summer e...
# 2    ill never know go put lousy rotten show boy to...
# 3    making somebody happy question give take learn...
# 4    making somebody happy question give take learn...
# Name: preprocessed_text, dtype: object

# %% [markdown]
# ## **Method 2** – Context Embeddings (SBERT)

# %% [markdown]
# Due to the size of the dataset and the effectiveness of Context Embeddings, SBERT will be used.

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")

# %%
def get_embeddings(text):
    return model.encode(text)

# Generating sentence embedding from the text
df['song_embeddings'] = df['preprocessed_text'].apply(get_embeddings)

# %% [markdown]
# ## **Method 3** – Clustering by Theme (KMeans, DBSCAN)

# %% [markdown]
# The two clustering methods that can be easily used on a large dataset are KMeans and DBSCAN. Both will be used in order to evaluate which preforms best.

# %% [markdown]
# ### Run KMeans

# %%
num_clusters = 20
kmeans_model = KMeans(n_clusters=num_clusters, random_state=42)
kmeans_model.fit(df['song_embeddings'].to_list())
df['kmeans_label'] = kmeans_model.labels_

# %% [markdown]
# ### Run DBSCAN

# %%
eps_dbscan = .8  # maximum distance between two samples for one to be considered as in the neighborhood of the other
min_samples_dbscan = 4  # number of samples in a neighborhood for a point to be considered as a core point
dbscan_model = DBSCAN(eps=eps_dbscan, min_samples=min_samples_dbscan)
dbscan_model.fit(df['song_embeddings'].tolist())
df['dbscan_label'] = dbscan_model.labels_

# %% [markdown]
# ### Output the top songs and words for each cluster

# %%
def extract_top_words(df, cluster_column, cluster_label, num_words):
    cluster_group = df[df[cluster_column] == cluster_label]
    cluster_text = ' '.join(cluster_group['preprocessed_text'])
    # Tokenize the text and count the occurrences of each word
    words = cluster_text.split()
    word_counts = pd.Series(words).value_counts()
    # Extract top words
    top_words = word_counts.index[:num_words].tolist()
    return top_words


def print_top_songs(df, cluster_column, clustering_model, num_songs=5, num_words=10):
    # Get unique cluster labels
    if isinstance(clustering_model, KMeans):
        num_clusters = clustering_model.n_clusters
    elif isinstance(clustering_model, DBSCAN):
        num_clusters = len(np.unique(clustering_model.labels_))
    else:
        raise ValueError("Unsupported clustering model.")
    
    # Iterate over each cluster label
    for cluster_label in range(num_clusters):
        # Count the number of songs in the cluster
        cluster_group = df[df[cluster_column] == cluster_label].copy()  # Explicitly create a copy
        cluster_count = len(cluster_group)
        
        # If the cluster has zero songs, print a message and continue to the next cluster
        if cluster_count == 0:
            print(f'Cluster "{cluster_label}": No songs in this cluster.')
            continue
        
        print(f'Cluster "{cluster_label}": ({cluster_count} songs)')
        
        # Extract key features of the cluster
        key_features = extract_top_words(cluster_group, cluster_column, cluster_label, num_words=num_words)
        print("Top words:", key_features)
        
        # Select songs and embeddings in the cluster
        cluster_embeddings = np.stack(cluster_group['song_embeddings'].to_numpy())
        
        if isinstance(clustering_model, KMeans):
            # Calculate centroid of the cluster
            centroid = clustering_model.cluster_centers_[cluster_label]
            # Calculate distance of each song's embedding from the centroid
            distances = [euclidean(embedding, centroid) for embedding in cluster_embeddings]
            
            # Add distances as a new column in the cluster group DataFrame
            cluster_group['distance_to_centroid'] = distances
            
            # Sort songs within the cluster based on distance to centroid
            sorted_cluster_group = cluster_group.sort_values(by='distance_to_centroid')
            
            # Print top songs closest to centroid
            for idx, row in sorted_cluster_group.head(num_songs).iterrows():
                print(f"- Song: {row['song']} by {row['artist']}")
            print()
        elif isinstance(clustering_model, DBSCAN):
            # Print the first songs
            for idx, row in cluster_group.head(num_songs).iterrows():
                print(f"- Song: {row['song']} by {row['artist']}")
            print()

# %%
print_top_songs(df, 'kmeans_label', kmeans_model, num_words = 15)
# Out:
# Cluster "0": (2886 songs)
# Top words: ['life', 'know', 'im', 'love', 'time', 'one', 'never', 'see', 'day', 'way', 'world', 'cant', 'go', 'like', 'heart']
# - Song: More Than You Know by Out Of Eden
# - Song: Best Days Of My Life by Hanson
# - Song: Change For A Better by Journey
# - Song: Shattered By The Sun by Unearth
# - Song: Walk Away by Westlife
#
# Cluster "1": (2412 songs)
# Top words: ['im', 'like', 'get', 'got', 'nigga', 'know', 'aint', 'yeah', 'go', 'cause', 'ya', 'see', 'shit', 'back', 'want']
# - Song: I Got One For Ya by Kid Rock
# - Song: Wait Up by Q-Tip
# - Song: We Don't Give A by Fabolous
# - Song: Be Easy by Wiz Khalifa
# - Song: Just Like Me by Usher
#
# Cluster "2": (2836 songs)
# Top words: ['know', 'see', 'im', 'time', 'like', 'eye', 'cant', 'go', 'one', 'way', 'away', 'get', 'want', 'say', 'look']
# - Song: Another Day by Dream Theater
# - Song: Move With Me by Lenny Kravitz
# - Song: Something Better by Natalie Imbruglia
# - Song: The Ones Who Help To Set The Sun by Dream Theater
# - Song: Directions by Our Lady Peace
#
# Cluster "3": (3714 songs)
# Top words: ['im', 'got', 'get', 'know', 'go', 'like', 'oh', 'time', 'gonna', 'well', 'one', 'man', 'back', 'aint', 'way']
# - Song: Chain Gang by Johnny Cash
# - Song: Rainy Day Crossroad Blues by Doobie Brothers
# - Song: Do It Again by Tori Amos
# - Song: I Hope It Rains At My Funeral by Tom T. Hall
# - Song: End O' The Line by You Am I
#
# Cluster "4": (2994 songs)
# Top words: ['im', 'know', 'time', 'like', 'ive', 'cant', 'get', 'want', 'never', 'love', 'say', 'go', 'got', 'one', 'feel']
# - Song: Waiting For That Day by George Michael
# - Song: Nothing But You And Me by Yo La Tengo
# - Song: How I Feel by Kelly Clarkson
# - Song: All That We Let In by Indigo Girls
# - Song: Free In You by Indigo Girls
#
# Cluster "5": (3850 songs)
# Top words: ['love', 'time', 'know', 'im', 'oh', 'day', 'go', 'away', 'never', 'like', 'one', 'come', 'say', 'ill', 'see']
# - Song: In The Blue by Kelly Clarkson
# - Song: Little Thing by Dave Matthews Band
# - Song: Daddy's Tune by Jackson Browne
# - Song: Finger Lakes by Nick Drake
# - Song: She Never Heard Me Call by Air Supply
#
# Cluster "6": (2654 songs)
# Top words: ['baby', 'love', 'im', 'know', 'oh', 'want', 'got', 'like', 'yeah', 'come', 'go', 'little', 'girl', 'let', 'you']
# - Song: I'll Be Back For More by 'n Sync
# - Song: Bliss by John Legend
# - Song: Two Fine People by Cat Stevens
# - Song: Baby Please Don't Go by Vince Gill
# - Song: Wasted Time by Il Divo
#
# Cluster "7": (3172 songs)
# Top words: ['oh', 'got', 'go', 'like', 'love', 'im', 'yeah', 'get', 'know', 'come', 'baby', 'let', 'night', 'la', 'well']
# - Song: One Of Those Nights by Tim McGraw
# - Song: Low Down Dirty by Lynyrd Skynyrd
# - Song: Your Mama Don't Dance by Kenny Loggins
# - Song: Mr. Natural by Janis Joplin
# - Song: What I Got by Sublime
#
# Cluster "8": (3232 songs)
# Top words: ['love', 'day', 'like', 'night', 'see', 'oh', 'come', 'sky', 'know', 'time', 'sun', 'eye', 'light', 'go', 'im']
# - Song: Rivendell by Rush
# - Song: Under A Glass Moon by Dream Theater
# - Song: Sunset by Roxy Music
# - Song: Here In My Dreams (C.H.Jennings) by Hollies
# - Song: Deep Blue Heart by John Mellencamp
#
# Cluster "9": (3389 songs)
# Top words: ['love', 'im', 'know', 'heart', 'never', 'oh', 'time', 'feel', 'like', 'want', 'let', 'chorus', 'cant', 'go', 'one']
# - Song: Without You by Kyla
# - Song: All Because Of You by Cher
# - Song: Only Love Knows Why by Peter Cetera
# - Song: How Could You Leave by Regine Velasquez
# - Song: Always Summer by Yellowcard
#
# Cluster "10": (3503 songs)
# Top words: ['love', 'know', 'heart', 'im', 'never', 'want', 'one', 'like', 'time', 'oh', 'say', 'need', 'let', 'feel', 'you']
# - Song: I Guess I'll Always Love You by Isley Brothers
# - Song: I Guess I'll Always Love You by Diana Ross
# - Song: In The Name Of Love by Rick Astley
# - Song: Forever In Your Heart by 'n Sync
# - Song: From The Heart by Ray Charles
#
# Cluster "11": (2832 songs)
# Top words: ['love', 'im', 'oh', 'know', 'like', 'baby', 'got', 'let', 'yeah', 'go', 'come', 'want', 'one', 'cant', 'get']
# - Song: Let Go by Glen Campbell
# - Song: Foolin' Around by Usher
# - Song: You by Ed Sheeran
# - Song: Take It From Here by Justin Timberlake
# - Song: The Crab Song by Faith No More
#
# Cluster "12": (2616 songs)
# Top words: ['im', 'oh', 'like', 'got', 'know', 'get', 'go', 'come', 'one', 'love', 'man', 'say', 'well', 'time', 'back']
# - Song: Sugar Marie by John Mellencamp
# - Song: I Shall Be Free by Bob Dylan
# - Song: Pirate Flag by Kenny Chesney
# - Song: Mr. 17.5 by Young Jeezy
# - Song: My Friend by Jimi Hendrix
#
# Cluster "13": (2991 songs)
# Top words: ['im', 'like', 'oh', 'know', 'love', 'one', 'life', 'see', 'never', 'time', 'come', 'go', 'heart', 'take', 'cant']
# - Song: The Point by Jennifer Lopez
# - Song: Feel The Fire by Overkill
# - Song: Tornado Of Souls by Megadeth
# - Song: Living With The Big Lie by Marillion
# - Song: Black Curtains by Megadeth
#
# Cluster "14": (3748 songs)
# Top words: ['im', 'know', 'got', 'gonna', 'get', 'like', 'go', 'oh', 'chorus', 'time', 'love', 'want', 'let', 'come', 'yeah']
# - Song: I Get High by Fastball
# - Song: Ready, Set, Don't Go by Miley Cyrus
# - Song: Golden by America
# - Song: For The Record by Mariah Carey
# - Song: Let Me Ride by Reo Speedwagon
#
# Cluster "15": (2307 songs)
# Top words: ['im', 'know', 'like', 'world', 'want', 'one', 'get', 'people', 'man', 'got', 'go', 'time', 'cant', 'say', 'life']
# - Song: If by Joni Mitchell
# - Song: World So Corrupt by Ziggy Marley
# - Song: Story From A Thin Wall by Marillion
# - Song: Colours by Phil Collins
# - Song: Your Failure Is My Revenge by Unseen
#
# Cluster "16": (2192 songs)
# Top words: ['lord', 'god', 'love', 'jesus', 'oh', 'come', 'let', 'know', 'one', 'u', 'im', 'heart', 'praise', 'life', 'holy']
# - Song: Because Of Love by Natalie Grant
# - Song: Come Holy Spirit by Israel Houghton
# - Song: Our God Is Love by Hillsong
# - Song: Mission's Flame by Matt Redman
# - Song: All Praises To The King by Hillsong
#
# Cluster "17": (1778 songs)
# Top words: ['dream', 'love', 'im', 'know', 'night', 'see', 'come', 'like', 'one', 'oh', 'time', 'never', 'life', 'go', 'eye']
# - Song: Lover's Lullaby by Townes Van Zandt
# - Song: Tread Lightly by Kirsty Maccoll
# - Song: I JUST NEED MYSELF by Ocean Colour Scene
# - Song: Dreamlike State by Erasure
# - Song: Dreams To Dream by Linda Ronstadt
#
# Cluster "18": (871 songs)
# Top words: ['christmas', 'santa', 'day', 'oh', 'time', 'merry', 'year', 'love', 'one', 'come', 'know', 'im', 'bell', 'like', 'tree']
# - Song: Christmas Day by Christmas Songs
# - Song: Christmas Day by Michael W. Smith
# - Song: Hey Santa by Christmas Songs
# - Song: The Christmas Song by Demi Lovato
# - Song: Here Comes Santa Claus by Christmas Songs
#
# Cluster "19": (3210 songs)
# Top words: ['like', 'love', 'know', 'got', 'im', 'oh', 'one', 'go', 'day', 'get', 'girl', 'little', 'well', 'time', 'come']
# - Song: Mumbo Jumbo by Squeeze
# - Song: Groundhog's Day by Primus
# - Song: Awol by Eurythmics
# - Song: She's On The Zoom by Don Henley
# - Song: Total Ringo by Happy Mondays

# %%
print_top_songs(df, 'dbscan_label', dbscan_model, num_words = 15)
# Out:
# Cluster "0": (40162 songs)
# Top words: ['im', 'love', 'know', 'like', 'oh', 'got', 'time', 'go', 'get', 'baby', 'one', 'come', 'want', 'let', 'see']
# - Song: She's My Kind Of Girl by ABBA
# - Song: As Good As New by ABBA
# - Song: Cassandra by ABBA
# - Song: Chiquitita by ABBA
# - Song: Crazy World by ABBA
#
# Cluster "1": (4 songs)
# Top words: ['fortune', 'said', 'teller', 'told', 'im', 'love', 'next', 'looking', 'could', 'know', 'happy', 'fool', 'something', 'eye', 'left']
# - Song: Fortune Teller by Alison Krauss
# - Song: Fortune Teller by Rolling Stones
# - Song: Fortune Teller by Hollies
# - Song: Fortune Teller by Who
#
# Cluster "2": (8 songs)
# Top words: ['auld', 'lang', 'syne', 'o', 'well', 'cup', 'kindness', 'yet', 'acquaintance', 'forgot', 'dear', 'take', 'brought', 'never', 'mind']
# - Song: Auld Lang Syne by Barbra Streisand
# - Song: Auld Lang Syne by Beach Boys
# - Song: Auld Lang Syne by Harry Connick, Jr.
# - Song: Auld Lang Syne (The New Year's Anthem) by Mariah Carey
# - Song: Auld Lang Syne by Neil Diamond
#
# Cluster "3": (5 songs)
# Top words: ['hill', 'blueberry', 'still', 'thrill', 'found', 'apart', 'love', 'were', 'never', 'made', 'vow', 'melody', 'sweet', 'played', 'willow']
# - Song: Blueberry Hill by Beach Boys
# - Song: Blueberry Hill by Conway Twitty
# - Song: Blueberry Hill by Andy Williams
# - Song: Blueberry Hill by Cliff Richard
# - Song: Blueberry Hill by Louis Armstrong
#
# Cluster "4": (5 songs)
# Top words: ['john', 'brian', 'paul', 'oh', 'it', 'ha', 'you', 'good', 'ringo', 'well', 'yeah', 'george', 'now', 'no', 'right']
# - Song: Dear Wack! by The Beatles
# - Song: Have A Banana! by The Beatles
# - Song: A Little Rhyme by The Beatles
# - Song: Crinsk Dee Night by The Beatles
# - Song: Don't Ever Change by The Beatles
#
# Cluster "5": (6 songs)
# Top words: ['get', 'back', 'belonged', 'home', 'jojo', 'man', 'loretta', 'thought', 'jo', 'go', 'woman', 'coming', 'girl', 'another', 'sweet']
# - Song: Get Back by The Beatles
# - Song: Get Back by Paul McCartney
# - Song: Get Back by Elton John
# - Song: Get Back by Glee
# - Song: Get Back by Grateful Dead
#
# Cluster "6": (5 songs)
# Top words: ['peace', 'give', 'saying', 'chance', 'talking', 'everybodys', 'hare', 'bishop', 'ism', 'krishna', 'everybody', 'tagism', 'canister', 'banister', 'minister']
# - Song: Give Peace A Chance by The Beatles
# - Song: Rest In Peace by Extreme
# - Song: Give Peace A Chance by Elton John
# - Song: Give Peace A Chance by Louis Armstrong
# - Song: Give Peace A Chance by Yoko Ono
#
# Cluster "7": (9 songs)
# Top words: ['help', 'please', 'me', 'im', 'younger', 'ive', 'foot', 'appreciate', 'ground', 'back', 'get', 'never', 'changed', 'need', 'feeling']
# - Song: Help! by The Beatles
# - Song: Help by Carpenters
# - Song: Help by Deep Purple
# - Song: Help by Roxette
# - Song: Help by Dolly Parton
#
# Cluster "8": (4 songs)
# Top words: ['new', 'year', 'eve', 'one', 'id', 'maybe', 'stand', 'im', 'little', 'crazy', 'suppose', 'chance', 'ever', 'chose', 'come']
# - Song: What Are You Doing New Year's Eve? by Bette Midler
# - Song: What Are You Doing New Year's Eve? by Carpenters
# - Song: What Are You Doing New Year's Eve? by Harry Connick, Jr.
# - Song: What Are You Doing New Year's Eve by Vonda Shepard
#
# Cluster "9": (5 songs)
# Top words: ['romance', 'fine', 'never', 'take', 'chance', 'like', 'good', 'seal', 'fellow', 'ill', 'jello', 'calmer', 'kiss', 'arctic', 'got']
# - Song: A Fine Romance by Billie Holiday
# - Song: Fine Romance by Bing Crosby
# - Song: A Fine Romance by Ella Fitzgerald
# - Song: A Fine Romance by Frank Sinatra
# - Song: A Fine Romance by Louis Armstrong
#
# Cluster "10": (4 songs)
# Top words: ['way', 'love', 'good', 'need', 'you', 'somebody', 'unless', 'thats', 'year', 'deep', 'cheer', 'happy', 'sure', 'let', 'would']
# - Song: All The Way by Billie Holiday
# - Song: All The Way by Celine Dion
# - Song: All The Way by Michael Bolton
# - Song: All The Way by Frank Sinatra
#
# Cluster "11": (4 songs)
# Top words: ['come', 'embraceable', 'sweet', 'love', 'me', 'many', 'you', 'baby', 'naughty', 'arm', 'want', 'charm', 'embrace', 'gypsy', 'bring']
# - Song: Embraceable You by Billie Holiday
# - Song: Embraceable You by Rod Stewart
# - Song: Embraceable You by Frank Sinatra
# - Song: Embraceable You by Gloria Estefan
#
# Cluster "12": (9 songs)
# Top words: ['many', 'blowin', 'wind', 'answer', 'man', 'must', 'yes', 'people', 'time', 'friend', 'sea', 'exist', 'year', 'theyre', 'see']
# - Song: Blowin' In The Wind by Bob Dylan
# - Song: Blowin' In The Wind by Dolly Parton
# - Song: Blowin' In The Wind by Cher
# - Song: Blowin' In The Wind by Cliff Richard
# - Song: Blowin' In The Wind by Elvis Presley
#
# Cluster "13": (6 songs)
# Top words: ['much', 'half', 'love', 'loved', 'miss', 'blue', 'worry', 'never', 'would', 'know', 'one', 'away', 'stay', 'build', 'around']
# - Song: Half As Much by Cake
# - Song: Half As Much by Hank Williams
# - Song: Half As Much by Hank Williams Jr.
# - Song: Half As Much by Patsy Cline
# - Song: Half As Much by Van Morrison
#
# Cluster "14": (9 songs)
# Top words: ['valentine', 'stay', 'day', 'little', 'hair', 'care', 'change', 'le', 'smart', 'speak', 'open', 'mouth', 'greek', 'figure', 'weak']
# - Song: My Funny Valentine by Chaka Khan
# - Song: My Funny Valentine by Christina Aguilera
# - Song: My Funny Valentine by Michael Bolton
# - Song: My Funny Valentine by Michael Buble
# - Song: My Funny Valentine by Rod Stewart
#
# Cluster "15": (6 songs)
# Top words: ['pretty', 'ribbon', 'blue', 'paper', 'love', 'wrap', 'present', 'pencil', 'write', 'busy', 'laughter', 'darling', 'better', 'midst', 'pas']
# - Song: Pretty Paper by Christmas Songs
# - Song: Pretty Paper by Don McLean
# - Song: Pretty Paper by Kenny Chesney
# - Song: Pretty Paper by Randy Travis
# - Song: Pretty Paper by Carly Simon
#
# Cluster "16": (6 songs)
# Top words: ['tennessee', 'memphis', 'information', 'marie', 'home', 'help', 'get', 'apart', 'touch', 'long', 'distance', 'me', 'time', 'know', 'call']
# - Song: Memphis by Chuck Berry
# - Song: Memphis by Hollies
# - Song: Memphis Tennessee by Tom Jones
# - Song: Memphis, Tenessee by The Beatles
# - Song: Memphis, Tennessee by Roy Orbison
#
# Cluster "17": (4 songs)
# Top words: ['get', 'kick', 'route', 'sixtysix', 'trip', 'go', 'hip', 'well', 'way', 'take', 'california', 'san', 'winona', 'city', 'forget']
# - Song: Route 66 by Chuck Berry
# - Song: Route 66 by Depeche Mode
# - Song: Route 66 by Nat King Cole
# - Song: Route 66 by Natalie Cole
#
# Cluster "18": (4 songs)
# Top words: ['easy', 'love', 'grand', 'cause', 'future', 'see', 'cant', 'shame', 'seem', 'together', 'carefree', 'game', 'im', 'burning', 'fire']
# - Song: Easy To Love by Cole Porter
# - Song: Easy To Love by Billie Holiday
# - Song: Easy To Love by Ella Fitzgerald
# - Song: Easy To Love by Judy Garland
#
# Cluster "19": (4 songs)
# Top words: ['one', 'thing', 'wed', 'dear', 'aware', 'love', 'affair', 'hot', 'cool', 'amen', 'painting', 'here', 'hoping', 'meet', 'great']
# - Song: Just One Of Those Things by Cole Porter
# - Song: Just One Of Those Things by Billie Holiday
# - Song: Just One Of Those Things by Nat King Cole
# - Song: Just One Of Those Things by Pogues
#
# Cluster "20": (6 songs)
# Top words: ['miss', 'otis', 'regret', 'unable', 'lunch', 'madam', 'today', 'lover', 'love', 'strung', 'shot', 'mob', 'came', 'got', 'dragged']
# - Song: Miss Otis Regrets by Cole Porter
# - Song: Miss Otis Regrets by Pogues
# - Song: Miss Otis Regrets by Bette Midler
# - Song: Miss Otis Regrets by Kirsty Maccoll
# - Song: Miss Otis Regrets by Linda Ronstadt
#
# Cluster "21": (4 songs)
# Top words: ['big', 'bos', 'man', 'cant', 'hear', 'call', 'thats', 'aint', 'tall', 'right', 'gonna', 'well', 'get', 'workin', 'all']
# - Song: Big Boss Man by Conway Twitty
# - Song: Big Boss Man by Elvis Presley
# - Song: Big Boss Man by Grateful Dead
# - Song: Big Boss Man by Steve Miller Band
#
# Cluster "22": (4 songs)
# Top words: ['si', 'bon', 'cest', 'good', 'every', 'oh', 'do', 'say', 'dear', 'would', 'thought', 'darling', 'one', 'rest', 'day']
# - Song: C'est Si Bon by Conway Twitty
# - Song: C'est Si Bon by Dean Martin
# - Song: C'est Si Bon by Barbra Streisand
# - Song: C'est Si Bon by Louis Armstrong
#
# Cluster "23": (4 songs)
# Top words: ['gotta', 'make', 'happen', 'worth', 'cigarette', 'alcohol', 'well', 'lifetime', 'top', 'come', 'line', 'white', 'sunshine', 'day', 'spend']
# - Song: Cigarettes And Alcohol by Counting Crows
# - Song: Cigarettes And Alcohol by Oasis
# - Song: Cigarretes Alcohol by Oasis
# - Song: Cigarettes And Alcohol by Rod Stewart
#
# Cluster "24": (4 songs)
# Top words: ['foggy', 'town', 'do', 'london', 'everywhere', 'day', 'shining', 'sun', 'saw', 'suddenly', 'long', 'british', 'museum', 'lost', 'charm']
# - Song: A Foggy Day by David Bowie
# - Song: A Foggy Day by Judy Garland
# - Song: A Foggy Day by Ella Fitzgerald
# - Song: A Foggy Day (In London Town) by Michael Buble
#
# Cluster "25": (4 songs)
# Top words: ['hero', 'day', 'one', 'nothing', 'could', 'oh', 'i', 'though', 'ever', 'u', 'were', 'beat', 'swim', 'keep', 'dolphin']
# - Song: Heroes by David Bowie
# - Song: Heroes by Oasis
# - Song: Heroes by One Direction
# - Song: Heroes by Peter Gabriel
#
# Cluster "26": (5 songs)
# Top words: ['make', 'door', 'closed', 'behind', 'know', 'lord', 'im', 'baby', 'one', 'hang', 'hair', 'let', 'go', 'get', 'glad']
# - Song: Behind Closed Doors by Diana Ross
# - Song: Behind Closed Doors by Loretta Lynn
# - Song: Behind Closed Doors by Tom Jones
# - Song: Behind Closed Doors by Dolly Parton
# - Song: Behind Closed Doors by Perry Como
#
# Cluster "27": (4 songs)
# Top words: ['get', 'ive', 'cant', 'started', 'im', 'dream', 'good', 'scheme', 'night', 'day', 'write', 'supreme', 'place', 'lyric', 'got']
# - Song: Can't Get Started With You by Diana Ross
# - Song: I Can't Get Started by Rod Stewart
# - Song: I Can't Get Started by Billie Holiday
# - Song: I Can't Get Starded by Ella Fitzgerald
#
# Cluster "28": (4 songs)
# Top words: ['mess', 'mister', 'inbetween', 'positive', 'negative', 'eliminate', 'latch', 'affirmative', 'illustrate', 'whale', 'last', 'remark', 'jonah', 'noah', 'got']
# - Song: Ac-Cent-Tchu-Ate The Positive by Ella Fitzgerald
# - Song: Accentuate The Positive by Perry Como
# - Song: Ac-Cent-Tchu-Ate The Positive by Bing Crosby
# - Song: Ac-Cent-Tchu-Ate The Positive by Paul McCartney
#
# Cluster "29": (4 songs)
# Top words: ['imagination', 'around', 'go', 'make', 'imagine', 'cant', 'think', 'want', 'yet', 'silly', 'example', 'wanting', 'felt', 'well', 'oh']
# - Song: Imagination by Ella Fitzgerald
# - Song: Imagination by Harry Connick, Jr.
# - Song: Imagination by Noa
# - Song: Imagination by Dean Martin
#
# Cluster "30": (5 songs)
# Top words: ['got', 'thing', 'ive', 'new', 'different', 'know', 'gave', 'still', 'used', 'little', 'picture', 'record', 'really', 'dear', 'look']
# - Song: He's Got You by Elvis Costello
# - Song: She's Got You by Leann Rimes
# - Song: She's Got You by Patsy Cline
# - Song: He's Got You by Dean Martin
# - Song: I've Got Your Picture by Patsy Cline
#
# Cluster "31": (4 songs)
# Top words: ['close', 'like', 'long', 'me', 'you', 'around', 'town', 'follow', 'decided', 'create', 'dream', 'true', 'come', 'got', 'blue']
# - Song: Close To You by Engelbert Humperdinck
# - Song: Close To You by Perry Como
# - Song: Close To You by Carpenters
# - Song: Close To You by Ella Fitzgerald
#
# Cluster "32": (5 songs)
# Top words: ['thought', 'im', 'you', 'star', 'eye', 'flower', 'every', 'love', 'face', 'see', 'idea', 'near', 'till', 'go', 'moment']
# - Song: The Very Thought Of You by Engelbert Humperdinck
# - Song: The Very Thought Of You by Harry Connick, Jr.
# - Song: The Very Thought Of You by Michael Bolton
# - Song: The Very Thought Of You by Andy Williams
# - Song: Very Thought Of You by Natalie Cole
#
# Cluster "33": (5 songs)
# Top words: ['aint', 'business', 'nobody', 'lord', 'nothing', 'do', 'day', 'im', 'say', 'right', 'next', 'one', 'take', 'jump', 'care']
# - Song: Ain't Nobody's Business If I Do by Eric Clapton
# - Song: Ain't Nobody's Business If I Do by Billie Holiday
# - Song: Ain't Nobody's Business by Freddie King
# - Song: Ain't Nobody's Business by Hank Williams Jr.
# - Song: Ain't Nobody's Business by Willie Nelson
#
# Cluster "34": (5 songs)
# Top words: ['jolene', 'take', 'please', 'man', 'im', 'begging', 'could', 'talk', 'like', 'though', 'even', 'you', 'name', 'call', 'keep']
# - Song: Jolene by Glee
# - Song: Jolene by Olivia Newton-John
# - Song: Jolene by Queen Adreena
# - Song: Jolene by Reba Mcentire
# - Song: Jolene by The White Stripes
#
# Cluster "35": (5 songs)
# Top words: ['he', 'brother', 'heavy', 'aint', 'know', 'im', 'long', 'strong', 'road', 'laden', 'get', 'enough', 'lead', 'turn', 'winding']
# - Song: He Ain't Heavy He's My Brother by Glen Campbell
# - Song: He Ain't Heavy, He's My Brother by Hollies
# - Song: He Ain't Heavy He's My Brother by Neil Diamond
# - Song: He Ain't Heavy...He's My Brother by Cher
# - Song: He Ain't Heavy, He's My Brother by Housemartins
#
# Cluster "36": (7 songs)
# Top words: ['he', 'got', 'hand', 'whole', 'world', 'everybody', 'baby', 'little', 'brother', 'bitty', 'sister', 'tiny', 'bitsy', 'the', 'wide']
# - Song: He's Got The Whole World In His Hands by Glen Campbell
# - Song: He's Got The Whole World In His Hands by Loretta Lynn
# - Song: He's Got The Whole World In His Hands by Nina Simone
# - Song: He's Got The Whole World In His Hands by Wanda Jackson
# - Song: He's Got The Whole World In His Hands by Children
#
# Cluster "37": (5 songs)
# Top words: ['home', 'little', 'go', 'baby', 'morning', 'good', 'withca', 'come', 'im', 'tell', 'schoolgirl', 'you', 'want', 'mama', 'schoolboy']
# - Song: Good Morning, Little Schoolgirl by Grateful Dead
# - Song: Good Morning Little Schoolgirl by Rod Stewart
# - Song: Good Morning Little Schoolgirl by Van Morrison
# - Song: Good Morning Little Schoolgirl by Allman Brothers Band
# - Song: Good Morning Little Schoolgirl by Ten Years After
#
# Cluster "38": (8 songs)
# Top words: ['law', 'fought', 'baby', 'feel', 'guess', 'best', 'run', 'race', 'ever', 'miss', 'girl', 'bad', 'left', 'cause', 'money']
# - Song: I Fought The Law by Green Day
# - Song: I Fought The Law by Hank Williams Jr.
# - Song: I Fought The Law by Nitty Gritty Dirt Band
# - Song: I Fought The Law by Bruce Springsteen
# - Song: I Fought The Law by Clash
#
# Cluster "39": (5 songs)
# Top words: ['rose', 'thought', 'fall', 'took', 'ground', 'trampled', 'like', 'way', 'world', 'die', 'laid', 'behind', 'stone', 'crucified', 'rejected']
# - Song: Above All by Hillsong United
# - Song: Above All by Randy Travis
# - Song: Above All by Michael W. Smith
# - Song: Above All by Point Of Grace
# - Song: Above All by Various Artists
#
# Cluster "40": (5 songs)
# Top words: ['king', 'im', 'never', 'tudor', 'thats', 'henry', 'welsh', 'said', 'verse', 'cause', 'richard', 'rule', 'queen', 'wale', 'england']
# - Song: Henry VII by Horrible Histories
# - Song: Mary Tudor Song by Horrible Histories
# - Song: The Tudors by Horrible Histories
# - Song: Owain Glyndwr by Horrible Histories
# - Song: Richard III by Horrible Histories
#
# Cluster "41": (6 songs)
# Top words: ['there', 'thief', 'along', 'u', 'get', 'save', 'said', 'watchtower', 'woman', 'know', 'two', 'take', 'reason', 'life', 'joke']
# - Song: All Along The Watchtower by Indigo Girls
# - Song: All Along The Watchtower by XTC
# - Song: All Along The Watchtower by Bob Dylan
# - Song: All Along The Watchtower by Dave Matthews Band
# - Song: All Along The Watchtower by Lenny Kravitz
#
# Cluster "42": (6 songs)
# Top words: ['come', 'hear', 'band', 'ragtime', 'alexander', 'along', 'honey', 'man', 'want', 'x', 'let', 'like', 'oh', 'land', 'take']
# - Song: Alexander's Ragtime Band by Irving Berlin
# - Song: Alexander's Ragtime Band by Bing Crosby
# - Song: Alexander's Ragtime Band by Ella Fitzgerald
# - Song: Alexander's Ragtime Band by Judy Garland
# - Song: Alexander's Ragtime Band by Louis Armstrong
#
# Cluster "43": (4 songs)
# Top words: ['love', 'one', 'doot', 'there', 'youre', 'cant', 'eagle', 'fly', 'rose', 'fisted', 'glove', 'dove', 'girl', 'away', 'honey']
# - Song: Love The One You're With by Isley Brothers
# - Song: Love The One You're With by Luther Vandross
# - Song: Love The One Your With by Bob Seger
# - Song: Love The One You're With by Indigo Girls
#
# Cluster "44": (6 songs)
# Top words: ['aint', 'well', 'mine', 'friend', 'rabbit', 'lie', 'time', 'dog', 'never', 'caught', 'hound', 'said', 'cry', 'high', 'nothin']
# - Song: Hound Dog by James Taylor
# - Song: Hound Dog by Jimi Hendrix
# - Song: Hound Dog by Roy Orbison
# - Song: Hound Dog by Status Quo
# - Song: Hound Dog by Grease
#
# Cluster "45": (5 songs)
# Top words: ['believed', 'makebelieve', 'love', 'without', 'world', 'phony', 'played', 'parade', 'penny', 'arcade', 'melody', 'barnum', 'bailey', 'hanging', 'muslin']
# - Song: It's Only A Paper Moon by James Taylor
# - Song: Between The Devil And The Deep Blue Sea by Ella Fitzgerald
# - Song: It's Only A Paper Moon by Nat King Cole
# - Song: Paper Moon by Natalie Cole
# - Song: It's Only A Paper Moon by Paul McCartney
#
# Cluster "46": (5 songs)
# Top words: ['aint', 'superstitious', 'come', 'well', 'thing', 'black', 'way', 'know', 'superstition', 'cat', 'luck', 'bad', 'crossed', 'trail', 'worry']
# - Song: Superstition by Lenny Kravitz
# - Song: How Come by Pogues
# - Song: I Ain't Superstitious by Rod Stewart
# - Song: Lifeline by Uriah Heep
# - Song: I Ain't Superstitious by Megadeth
#
# Cluster "47": (14 songs)
# Top words: ['valjean', 'cosette', 'thenardier', 'man', 'marius', 'come', 'know', 'eponine', 'he', 'must', 'let', 'away', 'javert', 'go', 'god']
# - Song: Bring Him Home by Les Miserables
# - Song: Stars by Les Miserables
# - Song: The Attack On Rue Plumet by Les Miserables
# - Song: The Robbery by Les Miserables
# - Song: The Waltz Of Treachery by Les Miserables
#
# Cluster "48": (5 songs)
# Top words: ['could', 'got', 'crush', 'frank', 'never', 'barbra', 'ive', 'cottage', 'care', 'coo', 'mush', 'pardon', 'world', 'share', 'baby']
# - Song: I've Got A Crush On You by Barbra Streisand
# - Song: I've Got A Crush On You by Linda Ronstadt
# - Song: I've Got A Crush On You by Rod Stewart
# - Song: I've Got A Crush On You by Diana Ross
# - Song: I've Got A Crush On You by Michael Buble
#
# Cluster "49": (4 songs)
# Top words: ['girl', 'blue', 'little', 'count', 'sit', 'raindrop', 'old', 'finger', 'well', 'fall', 'world', 'young', 'slender', 'cheer', 'boy']
# - Song: Little Girl Blue by Linda Ronstadt
# - Song: Little Girl Blue by Carly Simon
# - Song: Little Girl Blue by Diana Ross
# - Song: Little Girl Blue by Nina Simone
#
# Cluster "50": (9 songs)
# Top words: ['new', 'orleans', 'sun', 'house', 'rising', 'im', 'call', 'one', 'ruin', 'many', 'poor', 'oh', 'god', 'boy', 'mother']
# - Song: House Of The Rising Sun by Marianne Faithfull
# - Song: House Of The Rising Sun by Nina Simone
# - Song: House Of The Rising Sun by Toto
# - Song: The Saints Are Coming by U2
# - Song: House Of The Rising Sun by Bob Dylan
#
# Cluster "51": (5 songs)
# Top words: ['love', 'e', 'di', 'che', 'il', 'you', 'mimi', 'un', 'oh', 'le', 'sweet', 'amor', 'si', 'mine', 'non']
# - Song: E Lucevan Le Stelle by Michael Bolton
# - Song: Estate by Andrea Bocelli
# - Song: O Soave Fanciulla by Michael Bolton
# - Song: Recondita Armonia by Michael Bolton
# - Song: Una Furtiva Lagrima by Michael Bolton
#
# Cluster "52": (6 songs)
# Top words: ['im', 'love', 'aint', 'misbehavin', 'go', 'one', 'care', 'savin', 'radio', 'home', 'late', 'stay', 'corner', 'worth', 'kiss']
# - Song: Ain't Misbehavin' by Nat King Cole
# - Song: Ain't Misbehavin' by Perry Como
# - Song: Ain't Misbehavin' by Billie Holiday
# - Song: Ain't Misbehavin' by Hank Williams Jr.
# - Song: Ain't Misbehavin' by Louis Armstrong
#
# Cluster "53": (5 songs)
# Top words: ['he', 'another', 'whoopee', 'makin', 'say', 'think', 'make', 'judge', 'lot', 'picture', 'nest', 'love', 'year', 'whoopie', 'folk']
# - Song: Makin' Whoopee by Nat King Cole
# - Song: Makin' Whoopee by Rod Stewart
# - Song: Makin' Whoopee by Doris Day
# - Song: Makin' Whoopie by Louis Armstrong
# - Song: Makin' Whoopee by Ray Charles
#
# Cluster "54": (5 songs)
# Top words: ['calling', 'hear', 'desert', 'know', 'vega', 'nowhere', 'cant', 'coming', 'road', 'need', 'bend', 'around', 'cafe', 'little', 'machine']
# - Song: Calling You by Natalie Cole
# - Song: Calling You by Barbra Streisand
# - Song: Calling You by Celine Dion
# - Song: Calling You by George Michael
# - Song: Calling You by Queen
#
# Cluster "55": (4 songs)
# Top words: ['helpless', 'blue', 'leave', 'across', 'moon', 'yellow', 'star', 'behind', 'window', 'rise', 'u', 'big', 'flying', 'bird', 'sky']
# - Song: Helpless by Nazareth
# - Song: Helpless by Neil Young
# - Song: Helpless by Patti Smith
# - Song: Helpless by Nick Cave
#
# Cluster "56": (4 songs)
# Top words: ['bojangles', 'mr', 'dance', 'high', 'danced', 'said', 'shook', 'died', 'drink', 'jumped', 'year', 'head', 'shoe', 'pant', 'please']
# - Song: Mr. Bojangles by Neil Diamond
# - Song: Mr. Bojangles by Nitty Gritty Dirt Band
# - Song: Mr Bojangles by John Denver
# - Song: Mr. Bojangles by Robbie Williams
#
# Cluster "57": (5 songs)
# Top words: ['greensleeves', 'lady', 'green', 'sleeve', 'love', 'heart', 'gold', 'delight', 'joy', 'ala', 'company', 'delighting', 'long', 'wrong', 'loved']
# - Song: Greensleeves by Olivia Newton-John
# - Song: Leaving Green Sleeves by Leonard Cohen
# - Song: Greensleeves by Lynyrd Skynyrd
# - Song: Greensleeves by Marianne Faithfull
# - Song: Greensleeves by Perry Como
#
# Cluster "58": (4 songs)
# Top words: ['say', 'hello', 'goodbye', 'know', 'oh', 'go', 'why', 'hela', 'helloa', 'heba', 'no', 'yes', 'fall', 'bye', 'rise']
# - Song: Hello, Goodbye by The Beatles
# - Song: Hello Goodbye by Paul McCartney
# - Song: Hello Goodbye by Glee
# - Song: Seconds by U2
#
# Cluster "59": (4 songs)
# Top words: ['come', 'home', 'calling', 'jesus', 'tenderly', 'watching', 'mercy', 'oh', 'earnestly', 'weary', 'pleading', 'sinner', 'ye', 'softly', 'waiting']
# - Song: Softly And Tenderly by Randy Travis
# - Song: Softly And Tenderly by Selah
# - Song: Come Home by Indiana Bible College
# - Song: Softly And Tenderly by Loretta Lynn
#
# Cluster "60": (2 songs)
# Top words: ['hmm', 'sit', 'watch', 'tear', 'child', 'go', 'hear', 'day', 'evening', 'play', 'by', 'sing', 'sound', 'new', 'think']
# - Song: As Tears Go By by Marianne Faithfull
# - Song: As Tears Go By by Rolling Stones
#
# Cluster "61": (6 songs)
# Top words: ['better', 'make', 'da', 'jude', 'hey', 'let', 'nah', 'begin', 'remember', 'world', 'take', 'sad', 'song', 'heart', 'start']
# - Song: Hey Jude by Tom Jones
# - Song: Hey Jude by Elvis Presley
# - Song: Hey Jude by Grateful Dead
# - Song: Hey Jude by Paul McCartney
# - Song: Hey Jude by The Temptations
#
# Cluster "62": (6 songs)
# Top words: ['georgia', 'sweet', 'mind', 'song', 'old', 'keep', 'road', 'arm', 'eye', 'peace', 'back', 'lead', 'peaceful', 'see', 'tenderly']
# - Song: Georgia On My Mind by Van Morrison
# - Song: Georgia On My Mind by Ella Fitzgerald
# - Song: Georgia On My Mind by Louis Armstrong
# - Song: Georgia On My Mind by Michael Bolton
# - Song: Georgia On My Mind by Michael Buble
#
# Cluster "63": (4 songs)
# Top words: ['by', 'lullay', 'lully', 'child', 'day', 'poor', 'sing', 'thou', 'little', 'tiny', 'say', 'thee', 'young', 'slay', 'woe']
# - Song: Coventry Carol by Aled Jones
# - Song: Coventry Carol by John Denver
# - Song: Coventry Carol by Kenny Loggins
# - Song: Coventry Carol by Point Of Grace
#
# Cluster "64": (4 songs)
# Top words: ['suffragette', 'city', 'man', 'hey', 'oh', 'cause', 'lean', 'cant', 'know', 'back', 'time', 'aint', 'right', 'got', 'come']
# - Song: Suffragettes by Horrible Histories
# - Song: Suffragette City by Poison
# - Song: Suffragette City by Alice In Chains
# - Song: Suffragette City by Frankie Goes To Hollywood
#
# Cluster "65": (4 songs)
# Top words: ['hey', 'robinson', 'mr', 'wo', 'know', 'place', 'pray', 'please', 'hold', 'heaven', 'bless', 'god', 'love', 'jesus', 'you']
# - Song: Mrs. Robinson by The Beatles
# - Song: Mrs. Robinson by Bon Jovi
# - Song: Mrs. Robinson by Oasis
# - Song: Mrs.Robinson by Paul Simon
#
# Cluster "66": (4 songs)
# Top words: ['new', 'york', 'autumn', 'city', 'live', 'good', 'hand', 'love', 'often', 'mingled', 'dreamer', 'empty', 'land', 'sigh', 'exotic']
# - Song: Autumn In New York by Louis Armstrong
# - Song: Autumn In New York by Billie Holiday
# - Song: Another Rainy Day In New York City by Chicago
# - Song: Autumn In New York by Frank Sinatra
#
# Cluster "67": (4 songs)
# Top words: ['kick', 'get', 'see', 'im', 'you', 'would', 'one', 'even', 'sure', 'bore', 'took', 'terrifically', 'sniff', 'me', 'too']
# - Song: I Get A Kick Out Of You by Billie Holiday
# - Song: I Get A Kick Out Of You by Dolly Parton
# - Song: I Get A Kick Out Of You by Ella Fitzgerald
# - Song: I Get A Kick Out Of You by Norah Jones
#
# Cluster "68": (4 songs)
# Top words: ['aint', 'me', 'son', 'one', 'fortunate', 'folk', 'ooh', 'lord', 'yeah', 'born', 'more', 'millionaire', 'hail', 'door', 'made']
# - Song: Fortunate Son by Bob Seger
# - Song: Fortunate Son by Creedence Clearwater Revival
# - Song: Fortunate Son by Pearl Jam
# - Song: Fortunate Son by U2
#
# Cluster "69": (4 songs)
# Top words: ['beautiful', 'know', 'world', 'everywhere', 'people', 'go', 'wonderful', 'say', 'inside', 'life', 'live', 'place', 'you', 'bring', 'let']
# - Song: Everywhere You Go by Bing Crosby
# - Song: Beautiful People by Chris Brown
# - Song: Beautiful World by Devo
# - Song: Beautiful World by Rage Against The Machine
#
# Cluster "70": (4 songs)
# Top words: ['must', 'oh', 'tell', 'die', 'next', 'whiskey', 'lost', 'ask', 'know', 'why', 'moon', 'alabama', 'find', 'old', 'goodbye']
# - Song: Alabama Song by Bette Midler
# - Song: Alabama Song by Doors
# - Song: Alabama Song by Marianne Faithfull
# - Song: Moon Over Alabama by Nina Simone
#
# Cluster "71": (4 songs)
# Top words: ['man', 'handsome', 'brown', 'eyed', 'back', 'browneyed', 'woman', 'world', 'beautiful', 'daughter', 'three', 'walking', 'good', 'since', 'year']
# - Song: Brown Eyed Handsome Man by Elvis Presley
# - Song: Brown-eyed Handsome Man by Johnny Cash
# - Song: Brown Eyed Handsome Man by Paul McCartney
# - Song: Brown Eyed Handsome Man by Waylon Jennings
#
# Cluster "72": (4 songs)
# Top words: ['congratulation', 'someone', 'fool', 'happy', 'made', 'love', 'know', 'world', 'im', 'heart', 'thought', 'somehow', 'guess', 'alone', 'wish']
# - Song: Congratulations by Cliff Richard
# - Song: Congratulations To Someone by Louis Armstrong
# - Song: Congratulations by Reba Mcentire
# - Song: Congratulations by George Harrison
#
# Cluster "73": (4 songs)
# Top words: ['lead', 'long', 'ive', 'road', 'door', 'time', 'many', 'way', 'winding', 'left', 'standing', 'know', 'leave', 'never', 'waiting']
# - Song: The Long And Winding Road by George Michael
# - Song: The Long And Winding Road by Kate Bush
# - Song: The Long And Winding Road by Regine Velasquez
# - Song: Long And Winding Road by Tom Jones
#
# Cluster "74": (5 songs)
# Top words: ['got', 'little', 'tenderness', 'yeah', 'try', 'gotta', 'never', 'hold', 'oh', 'love', 'squeeze', 'get', 'gentle', 'her', 'leave']
# - Song: Try A Little Tenderness by Harry Connick, Jr.
# - Song: Try A Little Tenderness by Michael Bolton
# - Song: Try A Little Tenderness by Michael Buble
# - Song: Buck by Nina Simone
# - Song: Try A Little Tenderness by Otis Redding
#
# Cluster "75": (4 songs)
# Top words: ['friend', 'mine', 'never', 'many', 'still', 'love', 'cause', 'yeah', 'keep', 'road', 'cried', 'cant', 'cryin', 'im', 'died']
# - Song: Friend Of Mine by Bill Withers
# - Song: He Was A Friend Of Mine by Bob Dylan
# - Song: My Friends Have by Marianne Faithfull
# - Song: He Was A Friend Of Mine by Willie Nelson
#
# Cluster "76": (4 songs)
# Top words: ['spider', 'creepy', 'crawly', 'he', 'night', 'crawling', 'boris', 'think', 'there', 'forget', 'see', 'end', 'wall', 'feel', 'miss']
# - Song: Spider by Oingo Boingo
# - Song: Spiders by Ozzy Osbourne
# - Song: Spiders In The Night by Ozzy Osbourne
# - Song: Boris The Spider by Who
#
# Cluster "77": (4 songs)
# Top words: ['gonna', 'searchin', 'find', 'know', 'yeah', 'ill', 'ive', 'im', 'way', 'every', 'like', 'mountain', 'oh', 'child', 'well']
# - Song: It'll Be Me by Cliff Richard
# - Song: Searchin' by Grateful Dead
# - Song: Searchin' by Hollies
# - Song: Searchin' by Wanda Jackson
#
# Cluster "78": (4 songs)
# Top words: ['sunday', 'bloody', 'long', 'tonight', 'wipe', 'away', 'tear', 'belfast', 'go', 'cry', 'glory', 'eye', 'brigade', 'oh', 'one']
# - Song: Sunday Bloody Sunday by O.A.R.
# - Song: Sunday Bloody Sunday by U2
# - Song: Belfast Brigade by Christy Moore
# - Song: Sunday, Bloody Sunday by Yoko Ono
#
# Cluster "79": No songs in this cluster.

# %% [markdown]
# After tweaking the results and evaluating the outcomes, KMeans is the better choice for this dataset and our chosen feature engineering.

# %% [markdown]
# ### Give the clusters labels

# %% [markdown]
# ChatGPT is used to come up with more descriptive labels for each of the clusters.

# %%
kmeans_label_dict = {
    0: "Life Reflections",
    1: "Urban Vibes",
    2: "Introspective Moments",
    3: "Dynamic Energy",
    4: "Emotional Journeys",
    5: "Melancholic Moods",
    6: "Romantic Whispers",
    7: "Nightlife Chronicles",
    8: "Skyward Serenity",
    9: "Heartfelt Longings",
    10: "Enduring Affections",
    11: "Casual Affections",
    12: "Everyday Musings",
    13: "Soulful Expressions",
    14: "Eclectic Beats",
    15: "Worldly Observations",
    16: "Spiritual Devotions",
    17: "Dreamy Escapes",
    18: "Festive Cheer",
    19: "Lighthearted Moments"
}

# %%
df['kmeans_label_text'] = df['kmeans_label'].map(kmeans_label_dict)

# %% [markdown]
# Let's take a look at some random records.

# %%
df.sample(n=5)
# Out:
#              artist                 song  \
# 44935   Neil Sedaka  I Let You Walk Away
# 4353   Donna Summer   I Don't Wanna Work
# 50877       Santana               My Man
# 44918   Neil Sedaka        Calendar Girl
# 12485   Matt Redman               Gloria
#
#                                                    link  \
# 44935  /n/neil+sedaka/i+let+you+walk+away_20247423.html
# 4353    /d/donna+summer/i+dont+wanna+work_10087984.html
# 50877                   /s/santana/my+man_20535819.html
# 44918        /n/neil+sedaka/calendar+girl_20169378.html
# 12485               /m/matt+redman/gloria_21028003.html
#
#                                                     text  \
# 44935  I believe that nothing lasts forever  \nPromis...
# 4353   Well I give it little care  \nDoes anybody out...
# 50877  Boom Boom Boom  \nSantana's in the room  \nBoo...
# 44918  I love, I love, I love my calender girl  \nYea...
# 12485  The skies are filled with Your glory  \nThe oc...
#
#                                        preprocessed_text  \
# 44935  believe nothing last forever promise help u st...
# 4353   well give little care anybody even know im her...
# 50877  boom boom boom santanas room boom boom boom ma...
# 44918  love love love calender girl yeah sweet calend...
# 12485  sky filled glory ocean mirror grace deep high ...
#
#                                          song_embeddings  kmeans_label  \
# 44935  [-0.057967935, 0.004077129, 0.06776754, -0.012...             0
# 4353   [-0.09957706, -0.13900116, 0.05114976, 0.04368...             4
# 50877  [-0.081187785, -0.13603832, 0.06563344, -0.025...            11
# 44918  [-0.07577728, -0.016359465, 0.119390465, 0.016...            18
# 12485  [-0.03303984, 0.029969208, 0.046279937, -0.089...            16
#
#        dbscan_label    kmeans_label_text
# 44935             0     Life Reflections
# 4353              0   Emotional Journeys
# 50877             0    Casual Affections
# 44918             0        Festive Cheer
# 12485             0  Spiritual Devotions

# %% [markdown]
# ## **Method 4** – Text Similarity (Recommendation System)

# %%
user_query = input("Give some input for your playlist: ")
query_embedding = get_embeddings(user_query)
# make a 2d array, changing the shape from (384,) to (1,384)
query_embedding_2d = query_embedding.reshape(1,-1)
# stack the vectors from every song into a 2d array, changing the shape from (57187,) to (57187,384)
song_embeddings_2d = np.stack(df['song_embeddings'].values)

similarity_scores = cosine_similarity(query_embedding_2d, song_embeddings_2d)

top_recommendations = np.argsort(similarity_scores.flatten())[::-1]

# Print top recommendations
print("Top recommended songs:")
for i in range(25):  # Print top 10 recommendations
    song_index = top_recommendations[i]
    song_title = df['song'].loc[song_index]
    artist = df['artist'].loc[song_index]
    print("Song:", song_title, "by", artist)
# Out:
# Enter your query: something isn't right
# Top recommended songs:
# Song: You Were Wrong by Freddie King
# Song: Right Or Wrong by Patsy Cline
# Song: Definition Of Wrong by Travis
# Song: Right Or Wrong by Wanda Jackson
# Song: What If by Coldplay
# Song: High Sierra by Linda Ronstadt
# Song: High Sierra by Dolly Parton
# Song: So Wrong by Patsy Cline
# Song: Mother Stands For Comfort by Kate Bush
# Song: It Ain't Right by Eric Clapton
# Song: I Need Something Stronger by Unkle
# Song: When Something Is Wrong With My Baby by Otis Redding
# Song: Not Right by Iggy Pop
# Song: Perfect World by Talking Heads
# Song: Am I Very Wrong? by Genesis
# Song: Which One Of Them by Garth Brooks
# Song: Stone Cold Heart by Incognito
# Song: Two Rights by Allman Brothers Band
# Song: It's Alright With Me by Harry Connick, Jr.
# Song: Wrong All Along by Cheap Trick
# Song: Is It Wrong (For Loving You) by Loretta Lynn
# Song: Cowboy Song by Arlo Guthrie
# Song: Check It by Gary Numan
# Song: Often by Robbie Williams
# Song: What If I by Bosson

# %% [markdown]
# ## Save the Data

# %% [markdown]
# The text data can be saved in a .csv file with the theme labels and none of the extra columns. The song embedding vectors can be saved as a .npy file to preserve all of the information necessary for the recomendation system.

# %%
np.save('Song_Embeddings.npy',song_embeddings_2d)

# %%
df_export = df.drop(columns=['text','preprocessed_text','song_embeddings','kmeans_label', 'dbscan_label'])
df_export.to_csv('Labeled_Song_Dataset.csv')
